# %% [markdown]
# # Exploratory Data Analysis

# %%
#import necessary packages
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
#import numeric dataframe to allow for easy graphing and visualization
full_flu_train = pd.read_csv('data/numeric_train')
flu_test_cln = pd.read_csv('data/numeric_test')

full_onehot_train = pd.read_csv('data/onehot_train')
full_onehot_test = pd.read_csv('data/onehot_test')

# %%
#visualizing distributions of the variables we are to predict
ax = sns.countplot(x='seasonal_vaccine', data=full_flu_train)
plt.title('Seasonal Vaccination Distribution')
for p in ax.patches:
    percentage = f'{100 * p.get_height() / len(full_flu_train):.1f}%\n'
    x = p.get_x() + p.get_width() / 2
    y = p.get_height()
    ax.annotate(percentage, (x, y), ha='center', va='center');
plt.savefig('./figures/seas_dist.pdf')

# %%
#visualizing distributions of the variables we are to predict
ax = sns.countplot(x='h1n1_vaccine', data=full_flu_train)
plt.title('H1N1 Vaccination Distribution')
for p in ax.patches:
    percentage = f'{100 * p.get_height() / len(full_flu_train):.1f}%\n'
    x = p.get_x() + p.get_width() / 2
    y = p.get_height()
    ax.annotate(percentage, (x, y), ha='center', va='center');
    
plt.savefig('./figures/h1n1_dist.pdf')

# %% [markdown]
# The seasonal flu vaccination rate (47%) is over double that of the H1N1 vaccination rate (21%) which is to be expected as the seasonal flu vaccine has been accepted and shown to be safe/effective for many years. The H1N1 vaccine was brand new and only administered for 1 flu season.

# %% [markdown]
# ## Correlations within the Data:

# %%
#Correlation coefficients between all variables
full_flu_train.corr()
# Out:
#                              respondent_id  h1n1_concern  h1n1_knowledge  \
# respondent_id                     1.000000      0.017896        0.003473
# h1n1_concern                      0.017896      1.000000        0.060828
# h1n1_knowledge                    0.003473      0.060828        1.000000
# behavioral_antiviral_meds        -0.008458      0.089866       -0.010450
# behavioral_avoidance              0.008912      0.229648        0.087194
# behavioral_face_mask             -0.006654      0.155757        0.029888
# behavioral_wash_hands             0.011212      0.291670        0.089690
# behavioral_large_gatherings       0.004455      0.254133       -0.047293
# behavioral_outside_home           0.009181      0.245404       -0.066479
# behavioral_touch_face             0.007606      0.245038        0.084633
# doctor_recc_h1n1                 -0.002178      0.136957        0.094135
# doctor_recc_seasonal              0.001131      0.120670        0.074376
# ...

# %% [markdown]
# ## Normalized Value Counts for Columns:

# %%
#showing proportions of each survey answer in every column
for c in full_onehot_train.columns:
    if c != 'respondent_id':
        print(full_onehot_train[c].value_counts(normalize=True))
        print("                        ")
# Out:
# 2.0    0.399408
# 1.0    0.305276
# 3.0    0.171902
# 0.0    0.123413
# Name: h1n1_concern, dtype: float64
#
# 1.0    0.550942
# 2.0    0.355225
# 0.0    0.093833
# Name: h1n1_knowledge, dtype: float64
#
# 0.0    0.951286
# 1.0    0.048714
# Name: behavioral_antiviral_meds, dtype: float64
#
# 1.0    0.727749
# 0.0    0.272251
# Name: behavioral_avoidance, dtype: float64
#
# 0.0    0.931067
# 1.0    0.068933
# Name: behavioral_face_mask, dtype: float64
#
# 1.0    0.825888
# 0.0    0.174112
# Name: behavioral_wash_hands, dtype: float64
#
# 0.0    0.642528
# 1.0    0.357472
# Name: behavioral_large_gatherings, dtype: float64
#
# 0.0    0.663721
# 1.0    0.336279
# Name: behavioral_outside_home, dtype: float64
#
# 1.0    0.678811
# 0.0    0.321189
# Name: behavioral_touch_face, dtype: float64
#
# 0.0    0.797506
# 1.0    0.202494
# Name: doctor_recc_h1n1, dtype: float64
#
# 0.0    0.696933
# 1.0    0.303067
# Name: doctor_recc_seasonal, dtype: float64
#
# 0.0    0.727038
# ...

# %% [markdown]
# ## Extracting Ordinal and Binary Data into Two DataFrames:

# %% [markdown]
# This dataframe is too large to use certain visualization techniques so here I am breaking it down into two dataframes, each consisting of a different datatype

# %%
binary_df = full_flu_train[[
       'behavioral_antiviral_meds', 'behavioral_avoidance',
       'behavioral_face_mask', 'behavioral_wash_hands',
       'behavioral_large_gatherings', 'behavioral_outside_home',
       'behavioral_touch_face', 'doctor_recc_h1n1', 'doctor_recc_seasonal',
       'chronic_med_condition', 'child_under_6_months', 'health_worker',
       'health_insurance', 'sex', 'marital_status',
       'rent_or_own', 'h1n1_vaccine', 'seasonal_vaccine']]

ordinal_df = full_flu_train[[ 'h1n1_concern', 'h1n1_knowledge',
       'opinion_h1n1_vacc_effective', 'opinion_h1n1_risk',
       'opinion_h1n1_sick_from_vacc', 'opinion_seas_vacc_effective',
       'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group',
       'education', 'income_poverty', 
    'employment_status', 'census_msa',
       'household_adults', 'household_children', 
       'h1n1_vaccine', 'seasonal_vaccine']]

# %% [markdown]
# ## Binary Data Heatmap:

# %%
#to visualize correlations between binary data
sns.heatmap(binary_df.corr(), linewidth=.01)
plt.title('Binary Data Heatmap')
plt.savefig('./figures/bin_heat.pdf') 
plt.show();

# %% [markdown]
# ## Ordinal Data Heatmap:

# %%
#to visualize correlations between ordinal data
sns.heatmap(ordinal_df.corr(), linewidth=.01)
plt.title('Ordinal Data Heatmap')
plt.savefig('./figures/ord_heat.pdf')  
plt.show();

# %% [markdown]
# ## Age Group vs Number of Children in Household:

# %%
r = stats.pearsonr(full_flu_train.household_children, full_flu_train.age_group)
print('Pearson Correlation Coefficient: ', r[0])
# Out:
# Pearson Correlation Coefficient:  -0.43766753440661976

# %%
ax = sns.catplot(x='age_group', col='household_children', data=full_flu_train, kind='count')
plt.savefig('./figures/age_child_corr.pdf') 
plt.show();

# %% [markdown]
# As respondent age goes up, the number of household children goes down (negatively correlated). The large majority of respondents have no household children and as the number of children increases, the distribution of respondents is shifted further and further left to younger age groups.

# %% [markdown]
# ## Reducing Time Out of Home vs Reducing Time at Large Gatherings:

# %%
r= stats.pearsonr(full_flu_train.behavioral_outside_home, full_flu_train.behavioral_large_gatherings)
print('Pearson Correlation Coefficient: ', r[0])
# Out:
# Pearson Correlation Coefficient:  0.5808811017594829

# %%
sns.catplot(x='behavioral_outside_home', hue='behavioral_large_gatherings', data=full_flu_train, kind='count')
plt.title('Reducing Time Out of Home vs Reducing Time at Large Gatherings')
plt.savefig('./figures/behav_corr.pdf')
plt.show();

# %% [markdown]
# This is one of the strongest correlations seen within the data but unfortunately it does not produce much insight. It is no surprise that those less likely to attend large gatherings are also those that are less likely to leave the home.

# %% [markdown]
# ## Opinion of Seasonal Risk vs Opinion of H1N1 Risk:

# %%
r = stats.pearsonr(full_flu_train.opinion_seas_risk, full_flu_train.opinion_h1n1_risk)
print('Pearson Correlation Coefficient: ', r[0])
# Out:
# Pearson Correlation Coefficient:  0.5629763589616432

# %%
sns.catplot(x='opinion_seas_risk', hue='opinion_h1n1_risk', data=full_flu_train, kind='count')
plt.title('Opinion of Seasonal Risk vs Opinion of H1N1 Risk')
plt.savefig('./figures/opin_corr.pdf')
plt.show();

# %% [markdown]
# This was another stronger correlation seen within the data but this one is a bit more insightful. It seems that opinions about the respondents risk of getting the seasonal flu without a vaccine are pretty similar to opinions about the catching H1N1 flu without vaccination.

# %% [markdown]
# ## Opinion on Effectiveness and Seasonal Vaccination:

# %%
r = stats.pearsonr(full_flu_train.seasonal_vaccine, full_flu_train.opinion_seas_vacc_effective)
print('Pearson Correlation Coefficient: ', r[0])
# Out:
# Pearson Correlation Coefficient:  0.35886878525139454

# %%
sns.catplot(x='opinion_seas_vacc_effective', hue='seasonal_vaccine', data=full_flu_train, kind='count')
plt.show();

# %% [markdown]
# This correlation is not surprising. Those who believe the seasonal flu vaccine is effective are more likely to receive it.

# %% [markdown]
# ## Age Group and Seasonal Vaccination:

# %%
r = stats.pearsonr(full_flu_train.seasonal_vaccine, full_flu_train.age_group)
print('Pearson Correlation Coefficient: ', r[0])
# Out:
# Pearson Correlation Coefficient:  0.2774542068602136

# %%
sns.catplot(x="age_group",hue='seasonal_vaccine',
                data=full_flu_train, kind="count")
plt.show();

# %% [markdown]
# There is a pretty clear trend when looking at age groups and vaccinations. As age increases, the proportion of people vaccinated increases as well.

# %% [markdown]
# ## Opinion of Seasonal Risk vs Seasonal Vaccination:

# %%
r = stats.pearsonr(full_flu_train.seasonal_vaccine, full_flu_train.opinion_seas_risk)
print('Pearson Correlation Coefficient: ', r[0])
# Out:
# Pearson Correlation Coefficient:  0.38691570331520153

# %%
sns.catplot(x="opinion_seas_risk",hue='seasonal_vaccine',
                data=full_flu_train, kind="count")
plt.show();

# %% [markdown]
# Unsurprisingly, as opinion about risk of getting seasonal flu increases, proportion of vaccinated respondents also increases.

# %% [markdown]
# ## Dr Reccomendation and Seasonal Vaccination:

# %%
r = stats.pearsonr(full_flu_train.seasonal_vaccine, full_flu_train.doctor_recc_seasonal)
print('Pearson Correlation Coefficient: ', r[0])
# Out:
# Pearson Correlation Coefficient:  0.36069588759186316

# %%
sns.catplot(x="doctor_recc_seasonal",hue='seasonal_vaccine',
                data=full_flu_train, kind="count")
plt.show();

# %% [markdown]
# It seems a doctors recommendation of seasonal flu vaccine has a considerable positive effect on numbers of vaccinated respondents.

# %% [markdown]
# ## Dr Reccomendation and H1N1 Vaccination:

# %%
r = stats.pearsonr(full_flu_train.h1n1_vaccine, full_flu_train.doctor_recc_h1n1)
print('Pearson Correlation Coefficient: ', r[0])
# Out:
# Pearson Correlation Coefficient:  0.39408570665048137

# %%
sns.catplot(x="doctor_recc_h1n1",hue='h1n1_vaccine',
                data=full_flu_train, kind="count")
plt.title('Dr Reccomendation and H1N1 Vaccination')
plt.savefig('./figures/recc_corr.pdf')
plt.show();

# %% [markdown]
# It seems a doctors recommendation of H1N1 flu vaccine has a considerable positive effect on numbers of respondents vaccinated for H1N1. Moderately higher correlation than between seasonal recommendation and seasonal vaccinations.

# %% [markdown]
# ## H1N1 Vaccincation and Seasonal Vaccination:

# %%
r = stats.pearsonr(full_flu_train.h1n1_vaccine, full_flu_train.seasonal_vaccine)
print('Pearson Correlation Coefficient: ', r[0])
# Out:
# Pearson Correlation Coefficient:  0.3771426530614459

# %%
sns.catplot(x='seasonal_vaccine', col='h1n1_vaccine', data=full_flu_train, kind='count')
plt.savefig('./figures/vacc_corr.pdf')
plt.show();

# %% [markdown]
# Getting one of these vaccinations is modestly correlated with getting the other. This makes intuitive sense as people's beliefs about risks and effectiveness of vaccines extend to all vaccines and not just individual ones.

# %% [markdown]
# # Conclusion:
# From initial exploration of the data, it seems there are no extremely strong correlations between any 2 independent variables and there are only minor correlations between independent variables and response variables. Some variables to keep an eye on moving forward are the presence of Dr recommendations, beliefs about risks/effectiveness of vaccines and age group's effect on vaccination rates.
#
# Some conclusions can be drawn about the demographics of the population being sampled. This sample is predominantly white, female, educated and above the poverty line. The large majority have no children in their household and limited contact with children under 6 months of age.
#
# I have decided to keep all columns regardless of correlations to make machine learning as robust as possible. If ML shows some columns to be redundant or not useful I will remove them in order to make the predicitons as efficient as possible.
